# %%
import requests
from bs4 import BeautifulSoup
import json

url = 'https://api.yelp.com/v3/businesses/search'
api_key = 'DInim1_NbhOv02ViJEgwEIQVbmxfSfMvtaPT_jBElbQKmCk9nOKckCUac4qS97v7HMibjCVDejAF0lipIaXmhdL0E6_V7ZfiLNnEqCm9WTha6orjBCF5XyhG-CA-YHYx'

def get_business(location, term, api_key):
    headers = {"Authorization": "Bearer %s" % api_key}
    
    data = []
    for offset in range(0, 1000, 50):
        params = {
            'limit': 50,
            'location': location.replace(' ', '+'),
            'term': term.replace(' ', '+'),
            'offset': offset
        }
        
        response = requests.get(url, headers=headers, params=params)
        if response.status_code == 200:
            data += response.json()['businesses']
        elif response.status_code == 400:
            print('400 Bad Request')
            break
    return data

# %%
malls = get_business('manila', 'mall', api_key)

# %%
malls
# Out:
# [{'id': 'z9BEfWMGGD_-MmsMTEToQA',
#   'alias': 'sm-mall-of-asia-pasay-2',
#   'name': 'SM Mall of Asia',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KnVvy9fGuR3UTFLjX0EXbw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sm-mall-of-asia-pasay-2?adjust_creative=y_ByilX2TEFYc8loA-TciA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y_ByilX2TEFYc8loA-TciA',
#   'review_count': 66,
#   'categories': [{'alias': 'shoppingcenters', 'title': 'Shopping Centers'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 14.535068, 'longitude': 120.982115},
#   'transactions': [],
#   'price': '₱₱',
#   'location': {'address1': 'SM Central Business Park I',
#    'address2': 'Island A, Bay City',
#    'address3': None,
#    'city': 'Pasay',
#    'zip_code': '1300',
#    'country': 'PH',
#    'state': 'NCR',
#    'display_address': ['SM Central Business Park I',
#     'Island A, Bay City',
#     'Pasay, 1300 Metro Manila',
#     'Philippines']},
# ...

# %%
len(malls)
# Out:
# 327

# %%
malls[10]
# Out:
# {'id': 'BfQkXm0vItVDcnWiSjvgLA',
#  'alias': 'ayala-center-makati-city',
#  'name': 'Ayala Center',
#  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/In83fr1GPLBfWzCdn0BPug/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/ayala-center-makati-city?adjust_creative=y_ByilX2TEFYc8loA-TciA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=y_ByilX2TEFYc8loA-TciA',
#  'review_count': 2,
#  'categories': [{'alias': 'shoppingcenters', 'title': 'Shopping Centers'}],
#  'rating': 5.0,
#  'coordinates': {'latitude': 14.5583514452294, 'longitude': 121.017939189102},
#  'transactions': [],
#  'location': {'address1': 'Ayala Avenue',
#   'address2': 'Makati Avenue and EDSA',
#   'address3': None,
#   'city': 'Makati City',
#   'zip_code': '1200',
#   'country': 'PH',
#   'state': 'NCR',
#   'display_address': ['Ayala Avenue',
#    'Makati Avenue and EDSA',
#    'Makati City, 1200 Metro Manila',
#    'Philippines']},
#  'phone': '+63327527272',
# ...
